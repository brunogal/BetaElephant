# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudeCoulombe/VIARENA/blob/master/Labos/Lab-loiDeKleiber/Premier_reseau_neurones-Kleiber.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ### Rappel - Fonctionnement d'un carnet web iPython
#
# * Pour exécuter le code contenu dans une cellule d'un carnet iPython, cliquez dans la cellule et faites (⇧↵, shift-enter)
# * Le code d'un carnet iPython s'exécute séquentiellement de haut en bas de la page. Souvent, l'importation d'une bibliothèque Python ou l'initialisation d'une variable est préalable à l'exécution d'une cellule située plus bas. Il est donc recommandé d'exécuter les cellules en séquence. Enfin, méfiez-vous des retours en arrière qui peuvent réinitialiser certaines variables.

# %% [markdown]
# # Mon premier réseau de neurones avec Keras
#
# ## Approximer une étrange loi de la nature directement à partir de données
#
# Vous allez créer votre premier réseau de neurones pour approximer une étrange loi de la nature directement à partir de données.
#
# La loi de Kleiber, formulée par le biologiste Max Kleiber dans les années 1930, postule que la consommation d'énergie (le métabolisme) des animaux, y compris les humains, varie comme la puissance 3/4 de leur masse corporelle. Cette loi fonctionne des bactéries jusqu'aux baleines mais demeure pour le moment sans explication physique ou géométrique satisfaisante.
#
# https://fr.wikipedia.org/wiki/Loi_de_Kleiber
#
# On peut légitimenent se questionner sur l'utilité d'un tel exercice? En fait, ce qui est «intéressant» c'est de constater que le réseau de neurones va apprendre «seul» à partir des données à approximer cette étrange loi de la nature.
#
# **Note**: Il n'est pas important de comprendre le détail du code informatique pour le moment. Ne vous inquiétez pas, des explications détaillées suivront bientôt.

# %% [markdown]
# # Acquisition des données...
#
# ### Source des données:
# http://sites.science.oregonstate.edu/~schaferd/Sleuth/data-sets.html
#
# Le **Fichier ex0826.csv** contenu dans l'archive **sleuth3csv.zip** a été renommé **LoiDeKleiber.csv** avec une entête en français
#
# Ramsey, F., & Schafer, D. (2012). The statistical sleuth: a course in methods of data analysis. Cengage Learning.

# %%
# Création d'un répertoire pour les données
! mkdir DATA

# %%
# Téléchargement des données depuis un référentiel sur le site GitHub
! wget "https://github.com/ClaudeCoulombe/VIARENA/blob/master/DATA/LoiDeKleiber.csv?raw=True" -O DATA/LoiDeKleiber.csv
# Out:
# --2024-07-13 08:13:55--  https://github.com/ClaudeCoulombe/VIARENA/blob/master/DATA/LoiDeKleiber.csv?raw=True
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ClaudeCoulombe/VIARENA/raw/master/DATA/LoiDeKleiber.csv [following]
# --2024-07-13 08:13:55--  https://github.com/ClaudeCoulombe/VIARENA/raw/master/DATA/LoiDeKleiber.csv
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ClaudeCoulombe/VIARENA/master/DATA/LoiDeKleiber.csv [following]
# --2024-07-13 08:13:55--  https://raw.githubusercontent.com/ClaudeCoulombe/VIARENA/master/DATA/LoiDeKleiber.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4693 (4.6K) [text/plain]
# Saving to: ‘DATA/LoiDeKleiber.csv’
#
# DATA/LoiDeKleiber.c 100%[===================>]   4.58K  --.-KB/s    in 0s
#
# 2024-07-13 08:13:55 (40.3 MB/s) - ‘DATA/LoiDeKleiber.csv’ saved [4693/4693]

# %% [markdown]
# # Quelques lignes de code...

# %% [markdown]
# ## Importation des bibliothèques Python

# %%
# Importation des bibliothèques Python
import tensorflow as tf
import numpy as np
import pandas as pd
print("Bibliothèques importées")
# Out:
# Bibliothèques importées

# %% [markdown]
# ## Fixer le hasard pour la reproductibilité
#
# La mise au point de réseaux de neurones implique certains processus aléatoires. Afin de pouvoir reproduire et comparer vos résultats d'expérience, vous fixez temporairement l'état aléatoire grâce à un germe aléatoire unique.
#
# Pendant la mise au point, vous fixez temporairement l'état aléatoire pour la reproductibilité mais vous répétez l'expérience avec différents germes ou états aléatoires et prenez la moyenne des résultats.
# <br/>
# ##### **Note**: Pour un système en production, vous ravivez simplement l'état  purement aléatoire avec l'instruction `GERME_ALEATOIRE = None`

# %%
import os

# Définir un germe aléatoire
GERME_ALEATOIRE = 1

# Définir un état aléatoire pour Python
os.environ['PYTHONHASHSEED'] = str(GERME_ALEATOIRE)

# Définir un état aléatoire pour Python random
import random
random.seed(GERME_ALEATOIRE)

# Définir un état aléatoire pour NumPy
import numpy as np
np.random.seed(GERME_ALEATOIRE)

# Définir un état aléatoire pour TensorFlow
import tensorflow as tf
tf.random.set_seed(GERME_ALEATOIRE)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

print("Germe aléatoire fixé")
# Out:
# Germe aléatoire fixé

# %% [markdown]
# ## Lecture des données

# %%
# Lecture des données
loi_kleiber_data = pd.read_csv("DATA/LoiDeKleiber.csv")
print("Données lues")
# Out:
# Données lues

# %% [markdown]
# ## Affichage des données

# %%
# Affichage de l'information de base sur le ju de données
loi_kleiber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NomCommun    95 non-null     object
#  1   Espece       95 non-null     object
#  2   Masse        95 non-null     float64
#  3   Metabolisme  95 non-null     float64
#  4   DureeDeVie   95 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 3.8+ KB

# %% [markdown]
# Le jeu de données comporte 95 exemples et 5 attributs: 'NomCommun', 'Espece', 'Masse', 'Metabolisme', 'DureeDeVie'[texte du lien](https://)

# %%
# Affichage d'un échantillon de 5 exemplaires choisis au hasard du jeu de données
loi_kleiber_data.sample(n=5,random_state=42)

# masse en kg
# métabolisme en kJ par jour
# Out:
#          NomCommun                  Espece  Masse  Metabolisme  DureeDeVie
# 68         Chamois     Rupicapra rupicapra  40.00       3140.0        21.0
# 22  Scaly anteater          Manis javanica   4.22        529.0        11.0
# 72       Wolverine                Gulogulo  12.70       2820.0        15.0
# 73          Badger             Meles meles  11.10       1440.0        16.0
# 0          Echidna  Tachiglossus aculeatus   2.50        302.0        14.0

# %% [markdown]
# ## Prétraitement des données

# %% [markdown]
# Extraction des attributs qui vont servir à la prédiction ou variables indépendantes.
#
# Rappelez-vous que nous cherchons à prédire le métabolisme à partir de la masse donc un seul attribut prédictif, la masse

# %%
from sklearn.preprocessing import StandardScaler

# Extraction des attributs qui vont servir è la prédiction ou variables indépendantes
# Rappelez-vous que nous cherchons à prédire le métabolisme à partir de la masse
# donc un seul attribut prédictif, la masse
attribut_predictif = loi_kleiber_data['Masse'].values.reshape(-1, 1)
# Normalisation de l'attribut-prédictif pour faciliter le travail de l'algorithme
normalisateur_attribut_predictif = StandardScaler()
normalisateur_attribut_predictif.fit(attribut_predictif)
attribut_predictif = normalisateur_attribut_predictif.transform(attribut_predictif)
print("Attribut prédictif extrait et normalisé")
# Out:
# Attribut prédictif extrait et normalisé

# %% [markdown]
# Extraction de l'attribut que l'on cherche à prédire ou attribut-cible ou variable dépendante.
#
# Rappelez-vous que nous cherchons à prédire le métabolismemdonc un seul attribut-cible, le métabolisme

# %%
# Extraction de l'attribut à prédire ou attribut-cible ou variable dépendante
# Rappelez-vous que nous cherchons à prédire le métabolisme
# donc un seul attribut-cible, le métabolisme
attribut_cible = loi_kleiber_data['Metabolisme'].values.reshape(-1, 1)
# Normalisation de l'attribut-cible pour faciliter le travail de l'algorithme
normalisateur_attribut_cible = StandardScaler()
normalisateur_attribut_cible.fit(attribut_cible)
attribut_cible = normalisateur_attribut_cible.transform(attribut_cible)
print("Attribut-cible extrait et normalisé")
# Out:
# Attribut-cible extrait et normalisé

# %% [markdown]
# ## Construction d'un réseau de neurones de type perceptron à trois couches:
# ### couche d'entrée, couche cachée, couche de sortie

# %%
# Construction d'un réseau de neurones de typ percptron à trois couches: couche d'entrée, couche cachée, couche de sortie
reseau_de_neurones = tf.keras.models.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1]),
                                                 tf.keras.layers.Dense(units=10, activation='relu'),
                                                 tf.keras.layers.Dense(units=1)])
# Affichage de l'architecture du réseau
print("Architecture du réseau de neurones:")
reseau_de_neurones.summary()
# Out:
# Architecture du réseau de neurones:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
#  dense_1 (Dense)             (None, 10)                20
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 33 (132.00 Byte)
# Trainable params: 33 (132.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compilation du réseau de neurones
# ### optimiseur: Adam
# ### taux d'apprentissage: 0.001
# ### fonction d'erreur: erreur quadratique moyenne ('mean_squared_error')

# %%
# Compilation du réseau de neurones - optimiseur: Adam, taux d'apprentissage: 0.001, fonction d'erreur: erreur quadratique moyenne (mean_squared_error)
reseau_de_neurones.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                           loss='mean_squared_error')

print("Réseau de neurones compilé")
# Out:
# Réseau de neurones compilé

# %% [markdown]
# ## Entraînement du réseau de neurones sur les données:
# ### attribut_predictif et attribut_cible
# ### pendant 500 itérations ou époques

# %%
# Entraînement du réseau sur les données: variable_explicative et variable_dependante, pendant 500 itérations ou époques
traces = reseau_de_neurones.fit(attribut_predictif,attribut_cible,epochs=500,verbose=1)
# Affichage de l'erreur à la fin de l'entraînement
print("Erreur à la fin:",traces.history['loss'][-1])
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 7ms/step - loss: 1.3312
# Epoch 2/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3194
# Epoch 3/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3131
# Epoch 4/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2971
# Epoch 5/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2887
# Epoch 6/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2751
# Epoch 7/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2689
# Epoch 8/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2560
# Epoch 9/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2460
# Epoch 10/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2343
# Epoch 11/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2252
# Epoch 12/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2183
# Epoch 13/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2066
# Epoch 14/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1981
# Epoch 15/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1933
# Epoch 16/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1808
# Epoch 17/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1741
# Epoch 18/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1662
# Epoch 19/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1596
# Epoch 20/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1481
# Epoch 21/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1441
# Epoch 22/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1347
# Epoch 23/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1257
# Epoch 24/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1221
# Epoch 25/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1147
# Epoch 26/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1045
# Epoch 27/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0998
# Epoch 28/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0918
# Epoch 29/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0885
# Epoch 30/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0812
# Epoch 31/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0750
# Epoch 32/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0660
# Epoch 33/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0599
# Epoch 34/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0542
# Epoch 35/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0501
# Epoch 36/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0452
# Epoch 37/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0367
# Epoch 38/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0336
# Epoch 39/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0275
# Epoch 40/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0213
# Epoch 41/500
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0135
# Epoch 42/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0083
# Epoch 43/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0060
# Epoch 44/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9996
# Epoch 45/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9919
# Epoch 46/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9871
# Epoch 47/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9832
# Epoch 48/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9775
# Epoch 49/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9714
# Epoch 50/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9664
# Epoch 51/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9627
# Epoch 52/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9586
# Epoch 53/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9537
# Epoch 54/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9469
# Epoch 55/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9431
# Epoch 56/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9383
# Epoch 57/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9334
# Epoch 58/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9270
# Epoch 59/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9235
# Epoch 60/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9191
# Epoch 61/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9142
# Epoch 62/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9083
# Epoch 63/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9030
# Epoch 64/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8988
# Epoch 65/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8955
# Epoch 66/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8899
# Epoch 67/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8862
# Epoch 68/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8806
# Epoch 69/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8773
# Epoch 70/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8727
# Epoch 71/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8682
# Epoch 72/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8623
# Epoch 73/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8590
# Epoch 74/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8542
# Epoch 75/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8489
# Epoch 76/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8467
# Epoch 77/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8407
# Epoch 78/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8350
# Epoch 79/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8328
# Epoch 80/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8281
# Epoch 81/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8230
# Epoch 82/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8183
# Epoch 83/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8130
# Epoch 84/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8096
# Epoch 85/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8050
# Epoch 86/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8003
# Epoch 87/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7946
# Epoch 88/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7893
# Epoch 89/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7852
# Epoch 90/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7816
# Epoch 91/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7760
# Epoch 92/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7729
# Epoch 93/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7682
# Epoch 94/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7642
# Epoch 95/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7592
# Epoch 96/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7526
# Epoch 97/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7501
# Epoch 98/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7433
# Epoch 99/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7388
# Epoch 100/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7343
# Epoch 101/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7318
# Epoch 102/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7266
# Epoch 103/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7204
# Epoch 104/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7146
# Epoch 105/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7124
# Epoch 106/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7052
# Epoch 107/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7004
# Epoch 108/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6968
# Epoch 109/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6919
# Epoch 110/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6865
# Epoch 111/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6831
# Epoch 112/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6754
# Epoch 113/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6730
# Epoch 114/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6655
# Epoch 115/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6607
# Epoch 116/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6555
# Epoch 117/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6509
# Epoch 118/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6481
# Epoch 119/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6423
# Epoch 120/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6356
# Epoch 121/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6292
# Epoch 122/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6254
# Epoch 123/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6205
# Epoch 124/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6140
# Epoch 125/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6097
# Epoch 126/500
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6043
# Epoch 127/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6002
# Epoch 128/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5936
# Epoch 129/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5884
# Epoch 130/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5816
# Epoch 131/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5782
# Epoch 132/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5712
# Epoch 133/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5673
# Epoch 134/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5630
# Epoch 135/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5559
# Epoch 136/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5517
# Epoch 137/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5464
# Epoch 138/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5381
# Epoch 139/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5354
# Epoch 140/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5286
# Epoch 141/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5220
# Epoch 142/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5196
# Epoch 143/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5134
# Epoch 144/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5052
# Epoch 145/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5022
# Epoch 146/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4952
# Epoch 147/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4915
# Epoch 148/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4828
# Epoch 149/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4779
# Epoch 150/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4740
# Epoch 151/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4691
# Epoch 152/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4608
# Epoch 153/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4567
# Epoch 154/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4502
# Epoch 155/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4471
# Epoch 156/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4410
# Epoch 157/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4352
# Epoch 158/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4284
# Epoch 159/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4231
# Epoch 160/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4187
# Epoch 161/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4118
# Epoch 162/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4052
# Epoch 163/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3998
# Epoch 164/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3962
# Epoch 165/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3902
# Epoch 166/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3862
# Epoch 167/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3806
# Epoch 168/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3734
# Epoch 169/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3672
# Epoch 170/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3643
# Epoch 171/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3566
# Epoch 172/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3514
# Epoch 173/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3491
# Epoch 174/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3419
# Epoch 175/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3377
# Epoch 176/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3307
# Epoch 177/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3257
# Epoch 178/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3223
# Epoch 179/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3142
# Epoch 180/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3107
# Epoch 181/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3066
# Epoch 182/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3005
# Epoch 183/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2943
# Epoch 184/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2919
# Epoch 185/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2841
# Epoch 186/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2824
# Epoch 187/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2756
# Epoch 188/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2697
# Epoch 189/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2672
# Epoch 190/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2615
# Epoch 191/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2565
# Epoch 192/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2511
# Epoch 193/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2477
# Epoch 194/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2446
# Epoch 195/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2398
# Epoch 196/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2351
# Epoch 197/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2301
# Epoch 198/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2250
# Epoch 199/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2199
# Epoch 200/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2160
# Epoch 201/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2139
# Epoch 202/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2075
# Epoch 203/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2060
# Epoch 204/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2004
# Epoch 205/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1965
# Epoch 206/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1915
# Epoch 207/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1901
# Epoch 208/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1847
# Epoch 209/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1817
# Epoch 210/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1762
# Epoch 211/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1729
# Epoch 212/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1703
# Epoch 213/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1677
# Epoch 214/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1634
# Epoch 215/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1583
# Epoch 216/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1561
# Epoch 217/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1517
# Epoch 218/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1487
# Epoch 219/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1455
# Epoch 220/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1430
# Epoch 221/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1391
# Epoch 222/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1361
# Epoch 223/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1338
# Epoch 224/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1306
# Epoch 225/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1283
# Epoch 226/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1252
# Epoch 227/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1206
# Epoch 228/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1196
# Epoch 229/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1152
# Epoch 230/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1127
# Epoch 231/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1116
# Epoch 232/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1074
# Epoch 233/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1055
# Epoch 234/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1025
# Epoch 235/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1001
# Epoch 236/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0984
# Epoch 237/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0961
# Epoch 238/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0943
# Epoch 239/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0917
# Epoch 240/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0884
# Epoch 241/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0871
# Epoch 242/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0854
# Epoch 243/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0826
# Epoch 244/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0803
# Epoch 245/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0790
# Epoch 246/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0777
# Epoch 247/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0746
# Epoch 248/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0729
# Epoch 249/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0716
# Epoch 250/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0700
# Epoch 251/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0688
# Epoch 252/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0669
# Epoch 253/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0644
# Epoch 254/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0633
# Epoch 255/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0623
# Epoch 256/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0599
# Epoch 257/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0590
# Epoch 258/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0572
# Epoch 259/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0563
# Epoch 260/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0547
# Epoch 261/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0542
# Epoch 262/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0524
# Epoch 263/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0509
# Epoch 264/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0497
# Epoch 265/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0490
# Epoch 266/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0475
# Epoch 267/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0467
# Epoch 268/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0460
# Epoch 269/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0443
# Epoch 270/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0440
# Epoch 271/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0425
# Epoch 272/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0414
# Epoch 273/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0408
# Epoch 274/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0397
# Epoch 275/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0389
# Epoch 276/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0381
# Epoch 277/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0374
# Epoch 278/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0371
# Epoch 279/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0358
# Epoch 280/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0353
# Epoch 281/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0344
# Epoch 282/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0339
# Epoch 283/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0330
# Epoch 284/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0328
# Epoch 285/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0318
# Epoch 286/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0316
# Epoch 287/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0310
# Epoch 288/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0302
# Epoch 289/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0297
# Epoch 290/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0293
# Epoch 291/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0287
# Epoch 292/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0281
# Epoch 293/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0276
# Epoch 294/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0275
# Epoch 295/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0268
# Epoch 296/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0264
# Epoch 297/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0260
# Epoch 298/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0257
# Epoch 299/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0254
# Epoch 300/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0247
# Epoch 301/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0244
# Epoch 302/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0240
# Epoch 303/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0238
# Epoch 304/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0233
# Epoch 305/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0230
# Epoch 306/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0227
# Epoch 307/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0223
# Epoch 308/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0222
# Epoch 309/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0217
# Epoch 310/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0215
# Epoch 311/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0213
# Epoch 312/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0210
# Epoch 313/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0207
# Epoch 314/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0203
# Epoch 315/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0202
# Epoch 316/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0198
# Epoch 317/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0196
# Epoch 318/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0194
# Epoch 319/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0192
# Epoch 320/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0190
# Epoch 321/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0187
# Epoch 322/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0185
# Epoch 323/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0183
# Epoch 324/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0182
# Epoch 325/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0180
# Epoch 326/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0177
# Epoch 327/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 328/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0174
# Epoch 329/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0172
# Epoch 330/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0171
# Epoch 331/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0169
# Epoch 332/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0167
# Epoch 333/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0166
# Epoch 334/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0165
# Epoch 335/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0163
# Epoch 336/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0162
# Epoch 337/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0161
# Epoch 338/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0160
# Epoch 339/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0158
# Epoch 340/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0158
# Epoch 341/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0156
# Epoch 342/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0155
# Epoch 343/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0154
# Epoch 344/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0153
# Epoch 345/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0152
# Epoch 346/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0151
# Epoch 347/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0150
# Epoch 348/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0149
# Epoch 349/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0149
# Epoch 350/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0148
# Epoch 351/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0147
# Epoch 352/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0146
# Epoch 353/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0145
# Epoch 354/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0145
# Epoch 355/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0144
# Epoch 356/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0143
# Epoch 357/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0143
# Epoch 358/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 359/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 360/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0140
# Epoch 361/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0139
# Epoch 362/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0138
# Epoch 363/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0135
# Epoch 364/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0134
# Epoch 365/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0130
# Epoch 366/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0128
# Epoch 367/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0125
# Epoch 368/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0123
# Epoch 369/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0121
# Epoch 370/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0118
# Epoch 371/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0117
# Epoch 372/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0114
# Epoch 373/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 374/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 375/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0108
# Epoch 376/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0107
# Epoch 377/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0105
# Epoch 378/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0103
# Epoch 379/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 380/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0101
# Epoch 381/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0099
# Epoch 382/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0098
# Epoch 383/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0097
# Epoch 384/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0095
# Epoch 385/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0094
# Epoch 386/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 387/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0092
# Epoch 388/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0091
# Epoch 389/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0090
# Epoch 390/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0089
# Epoch 391/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0088
# Epoch 392/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0087
# Epoch 393/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0086
# Epoch 394/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0085
# Epoch 395/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0084
# Epoch 396/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0084
# Epoch 397/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0083
# Epoch 398/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0083
# Epoch 399/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0083
# Epoch 400/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 401/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 402/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 403/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0082
# Epoch 404/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0082
# Epoch 405/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0081
# Epoch 406/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0081
# Epoch 407/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 408/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 409/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 410/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 411/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 412/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0080
# Epoch 413/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0080
# Epoch 414/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 415/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0079
# Epoch 416/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 417/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 418/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0079
# Epoch 419/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0079
# Epoch 420/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0079
# Epoch 421/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 422/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0078
# Epoch 423/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 424/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0078
# Epoch 425/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0078
# Epoch 426/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 427/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 428/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0077
# Epoch 429/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0077
# Epoch 430/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 431/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 432/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0077
# Epoch 433/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0077
# Epoch 434/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0077
# Epoch 435/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 436/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 437/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0077
# Epoch 438/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 439/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0076
# Epoch 440/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0076
# Epoch 441/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 442/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0076
# Epoch 443/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 444/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 445/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 446/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0076
# Epoch 447/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 448/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 449/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0075
# Epoch 450/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0075
# Epoch 451/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 452/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 453/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 454/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 455/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 456/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 457/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 458/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 459/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0075
# Epoch 460/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 461/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 462/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 463/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 464/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 465/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 466/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 467/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0074
# Epoch 468/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0074
# Epoch 469/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 470/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 471/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 472/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 473/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 474/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 475/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 476/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 477/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 478/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 479/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 480/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 481/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 482/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 483/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 484/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 485/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 486/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 487/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 488/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 489/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 490/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 491/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 492/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 493/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 494/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 495/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 496/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 497/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 498/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 499/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 500/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0072
# Erreur à la fin: 0.0071868267841637135

# %% [markdown]
# ### Test du réseau de neurones qui a été entraîné
# Vous allez valider la fonction que le réseau neuronal a apprise avec des données de test qui ne faisaient pas partie du jeu de données d'entraînement.

# %%
# Être humain, Homo sapiens
animal = "être humain"
masse = 6.50E+01
# Normalisation des données d'entrée
masse_normalisee = normalisateur_attribut_predictif.transform(np.array([masse]).reshape(-1, 1))
vraie_valeur_metabolisme = 7.56E+03
# Application du modèle en inférence ou prédiction de la variable dépendante et «dénormalisation» du résultat
prediction_metabolisme = normalisateur_attribut_cible.inverse_transform(reseau_de_neurones.predict(masse_normalisee))[0][0]
# Affichage de la prédiction, de la vraie valeur (mesurée) et de l'écart (ou erreur) en %
print("\nAnimal:", animal,
      ", Masse:", masse,
      ", prédiction du métabolisme:", round(prediction_metabolisme,2),
      ", Vraie valeur du métabolisme:", vraie_valeur_metabolisme,
      ", écart en %:", round((vraie_valeur_metabolisme-prediction_metabolisme)/vraie_valeur_metabolisme*100,2),"%")
# Out:
# 1/1 [==============================] - 0s 118ms/step
#
# Animal: être humain , Masse: 65.0 , prédiction du métabolisme: 8333.68 , Vraie valeur du métabolisme: 7560.0 , écart en %: -10.23 %

# %%
# Chat, Felis silvestris, 3.00E+00, 5.46E+02, 11
animal = "chat"
masse = 3.00E+00
# Normalisation des données d'entrée
masse_normalisee = normalisateur_attribut_predictif.transform(np.array([masse]).reshape(-1, 1))
vraie_valeur_metabolisme = 5.46E+02
# Application du modèle en inférence ou prédiction de l'attribut-cible et «dénormalisation» du résultat
prediction_metabolisme = normalisateur_attribut_cible.inverse_transform(reseau_de_neurones.predict(masse_normalisee))[0][0]
# Affichage de la prédiction, de la vraie valeur (mesurée) et de l'écart (ou erreur) en %
print("\nAnimal:", animal,
      ", Masse:", masse,
      ", prédiction du métabolisme:", round(prediction_metabolisme,2),
      ", Vraie valeur du métabolisme:", vraie_valeur_metabolisme,
      ", écart en %:", round((vraie_valeur_metabolisme-prediction_metabolisme)/vraie_valeur_metabolisme*100,2),"%")
# Out:
# 1/1 [==============================] - 0s 31ms/step
#
# Animal: chat , Masse: 3.0 , prédiction du métabolisme: 507.45 , Vraie valeur du métabolisme: 546.0 , écart en %: 7.06 %

# %%
# Cheval, Equus cabalus, 4.00E+02, 3.20E+04, 40
animal = "cheval"
masse = 4.00E+02
# Normalisation des données d'entrée
masse_normalisee = normalisateur_attribut_predictif.transform(np.array([masse]).reshape(-1, 1))
vraie_valeur_metabolisme = 3.20E+04
# Application du modèle en inférence ou prédiction de la variable dépendante et «dénormalisation» du résultat
prediction_metabolisme = normalisateur_attribut_cible.inverse_transform(reseau_de_neurones.predict(masse_normalisee))[0][0]
# Affichage de la prédiction, de la vraie valeur (mesurée) et de l'écart (ou erreur) en %
print("\nAnimal:", animal,
      ", Masse:", masse,
      ", prédiction du métabolisme:", round(prediction_metabolisme,2),
      ", Vraie valeur du métabolisme:", vraie_valeur_metabolisme,
      ", écart en %:", round((vraie_valeur_metabolisme-prediction_metabolisme)/vraie_valeur_metabolisme*100,2),"%")
# Out:
# 1/1 [==============================] - 0s 32ms/step
#
# Animal: cheval , Masse: 400.0 , prédiction du métabolisme: 31611.03 , Vraie valeur du métabolisme: 32000.0 , écart en %: 1.22 %

# %% [markdown]
# ### Conclusion
#
# Vous pouvez constater que le réseau de neurones retourne des valeurs assez proches des vraies valeurs données par la loi de Kleiber. Il est important de comprendre que le réseau de neurones n'apprend pas une formule exacte mais bien qu'il approxime itérativement une fonction.
#
# Choses à retenir:
#
# * Le réseau de neurones est capable d'apprendre à approximer une fonction directement à partir des données
# * Le processus d'apprentissage est itératif

# %%
print("Exécution du carnet web IPython terminée")
# Out:
# Exécution du carnet web IPython terminée
